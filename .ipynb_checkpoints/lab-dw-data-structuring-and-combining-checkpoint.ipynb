# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
import pandas as pd

url1 = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv"
df1 = pd.read_csv(url1)

df1.rename(columns=lambda col: col.replace(" ", "_").lower(), inplace=True)
df1 = df1.rename({"st":"state"}, axis = 1) 
df1.head()
# Out:
#   customer       state gender             education customer_lifetime_value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
url2 = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv"
df2 = pd.read_csv(url2)

df2.rename(columns=lambda col: col.replace(" ", "_").lower(), inplace=True)
df2 = df2.rename({"st":"state"}, axis = 1) 
df2.head()
# Out:
#   customer       state gender education customer_lifetime_value  income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    monthly_premium_auto number_of_open_complaints  total_claim_amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       policy_type  vehicle_class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
url3 = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv"
df3 = pd.read_csv(url3)

df3.rename(columns=lambda col: col.replace(" ", "_").lower(), inplace=True)
df3 = df3.rename({"st":"state"}, axis = 1) 
df3.head()
# Out:
#   customer       state  customer_lifetime_value             education gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    income  monthly_premium_auto  number_of_open_complaints    policy_type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    total_claim_amount  vehicle_class
# ...

# %%
df_combined = pd.concat([df1, df2, df3], axis=0, ignore_index=True)
df_combined
# Out:
#       customer       state gender             education  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 2      AI49188      Nevada      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 4      GA49547  Washington      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  California      M              Bachelor
# 12070  PK87824  California      F               College
# 12071  TD14365  California      M              Bachelor
# 12072  UP19263  California      M               College
# 12073  Y167826  California      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# 2                 1288743.17%  48767.0                 108.0
# ...

# %%
df_combined["gender"].value_counts()
# Out:
# gender
# F         4560
# M         4368
# Male        40
# female      30
# Femal       17
# Name: count, dtype: int64

# %%
df_combined["gender"] = df_combined["gender"].replace({
    'Femal': 'F',
    'female': 'F',
    'Female': 'F',
    'Male': 'M',
    'male': 'M'
})
df_combined["gender"].value_counts()
# Out:
# gender
# F    4607
# M    4408
# Name: count, dtype: int64

# %%
df_combined['state'] = df_combined['state'].replace({
    'AZ': 'Arizona',
    'WA': 'Washington',
})
df_combined["state"].value_counts()
# Out:
# state
# California    3032
# Oregon        2601
# Arizona       1704
# Nevada         882
# Washington     798
# Cali           120
# Name: count, dtype: int64

# %%
df_combined['education'] = df_combined['education'].replace({
    'Bachelors': 'Bachelor',
})
df_combined["education"].value_counts()
# Out:
# education
# Bachelor                2743
# College                 2682
# High School or Below    2616
# Master                   752
# Doctor                   344
# Name: count, dtype: int64

# %%
df_combined['customer_lifetime_value'] = df_combined['customer_lifetime_value'].str.replace('%', '') 
df_combined["customer_lifetime_value"].value_counts()
# Out:
# customer_lifetime_value
# 251459.20     5
# 552821.28     5
# 445811.34     4
# 343613.43     4
# 871704.98     4
#              ..
# 575991.08     1
# 1511440.24    1
# 988038.58     1
# 2919436.64    1
# 399258.39     1
# Name: count, Length: 1923, dtype: int64

# %%
df_combined['number_of_open_complaints'].unique
# Out:
# <bound method Series.unique of 0        1/0/00
# 1        1/0/00
# 2        1/0/00
# 3        1/0/00
# 4        1/0/00
#           ...
# 12069         0
# 12070         0
# 12071         3
# 12072         0
# 12073         0
# Name: number_of_open_complaints, Length: 12074, dtype: object>

# %%
df_combined['number_of_open_complaints'] = df_combined['number_of_open_complaints'].apply(lambda x:x.split('/')[1] if isinstance(x, str) else x)
df_combined
# Out:
#       customer       state gender             education  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 2      AI49188      Nevada      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 4      GA49547  Washington      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  California      M              Bachelor
# 12070  PK87824  California      F               College
# 12071  TD14365  California      M              Bachelor
# 12072  UP19263  California      M               College
# 12073  Y167826  California      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                   697953.59      0.0                  94.0
# 2                  1288743.17  48767.0                 108.0
# ...

# %%
dealing_null_df = df_combined.dropna(subset = ["customer", "state", "gender", "education","customer_lifetime_value", "income", "monthly_premium_auto", "number_of_open_complaints", "policy_type", "vehicle_class", "total_claim_amount"], thresh = 11)
dealing_null_df
# Out:
#      customer       state gender             education  \
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# 5     OC83172      Oregon      F              Bachelor
# ...       ...         ...    ...                   ...
# 4999  HV85198     Arizona      M                Master
# 5000  BS91566     Arizona      F               College
# 5001  IL40123      Nevada      F               College
# 5002  MY32149  California      F                Master
# 5003  SA91515  California      M              Bachelor
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 1                  697953.59      0.0                  94.0
# 2                 1288743.17  48767.0                 108.0
# 3                  764586.18      0.0                 106.0
# ...

# %%
dealing_null_df['customer_lifetime_value'] = dealing_null_df['customer_lifetime_value'].astype(float)
# Out:
# /var/folders/9k/2yrc93qj3w58wsw_h7nj8x1h0000gn/T/ipykernel_76185/1493774527.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dealing_null_df['customer_lifetime_value'] = dealing_null_df['customer_lifetime_value'].astype(float)

# %%
dealing_null_df = dealing_null_df.astype({'customer_lifetime_value': 'int', 'income': 'int', 'monthly_premium_auto': 'int', 'total_claim_amount': 'int'})
dealing_null_df.dtypes
# Out:
# customer                     object
# state                        object
# gender                       object
# education                    object
# customer_lifetime_value       int64
# income                        int64
# monthly_premium_auto          int64
# number_of_open_complaints    object
# policy_type                  object
# vehicle_class                object
# total_claim_amount            int64
# dtype: object

# %%
new_df_cleaned = dealing_null_df.drop_duplicates(keep='first')
new_df_cleaned
# Out:
#      customer       state gender             education  \
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# 5     OC83172      Oregon      F              Bachelor
# ...       ...         ...    ...                   ...
# 4999  HV85198     Arizona      M                Master
# 5000  BS91566     Arizona      F               College
# 5001  IL40123      Nevada      F               College
# 5002  MY32149  California      F                Master
# 5003  SA91515  California      M              Bachelor
#
#       customer_lifetime_value  income  monthly_premium_auto  \
# 1                      697953       0                    94
# 2                     1288743   48767                   108
# 3                      764586       0                   106
# ...

# %%
new_df_cleaned.reset_index()
# Out:
#       index customer       state gender             education  \
# 0         1  QZ44356     Arizona      F              Bachelor
# 1         2  AI49188      Nevada      F              Bachelor
# 2         3  WW63253  California      M              Bachelor
# 3         4  GA49547  Washington      M  High School or Below
# 4         5  OC83172      Oregon      F              Bachelor
# ...     ...      ...         ...    ...                   ...
# 1932   4999  HV85198     Arizona      M                Master
# 1933   5000  BS91566     Arizona      F               College
# 1934   5001  IL40123      Nevada      F               College
# 1935   5002  MY32149  California      F                Master
# 1936   5003  SA91515  California      M              Bachelor
#
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                      697953       0                    94
# 1                     1288743   48767                   108
# ...

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
url4 = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv"
marketing_df = pd.read_csv(url4)
marketing_df
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  California              6857.519928       No
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
#1 
marketing_df.pivot_table(index= "sales_channel", values = "total_claim_amount", aggfunc = "sum").round(2)
# Out:
#                total_claim_amount
# sales_channel
# Agent                  1810226.82
# Branch                 1301204.00
# Call Center             926600.82
# Web                     706600.04

# %% [raw]
# # Insights
#
# Agent sales channel is the most successful one, what could mean that the customers make the highest claim with the highest amounts directly to an agent rather using the other channels. Call center and web channels definately need improving, may be a good option to target more resources in oushing this ones.

# %%
#Create a pivot table that shows the average customer lifetime value per gender and education level. 
#Analyze the resulting table to draw insights.
#2

education_order = ["High School or Below", "College", "Bachelor", "Master", "Doctor"]
marketing_df['education'] = pd.Categorical(marketing_df['education'], categories=education_order, ordered=True)

marketing_df.pivot_table(index= "education", columns = "gender", values = "customer_lifetime_value", aggfunc = "mean").round(2)
# Out:
# /var/folders/9k/2yrc93qj3w58wsw_h7nj8x1h0000gn/T/ipykernel_76185/2393138953.py:8: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   marketing_df.pivot_table(index= "education", columns = "gender", values = "customer_lifetime_value", aggfunc = "mean").round(2)
# gender                      F        M
# education
# High School or Below  8675.22  8149.69
# College               7748.82  8052.46
# Bachelor              7874.27  7703.60
# Master                8157.05  8168.83
# Doctor                7328.51  7415.33

# %% [raw]
# The most profitable segments for the company are females and males with "High School or Below" education level and females and males with "Master" education level.
# Interesting to keep an eye on the Male-College segment, since they also have en high customer_lifetime_value average.
# We could conclude that the lower the education level the higher CLV average, but the group with a master education breaks this conclusion, so we would need to look further into the details.

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# Your code goes here
